# %%
import pandas as pd
import numpy as np

# Extracting data from database
import pymysql                 

# Establishing connection and authentication
from sqlalchemy import create_engine

from getpass import getpass

# %%
password = getpass()
# Out:
# ········

# %%
connection_string = 'mysql+pymysql://root:'+password+'@localhost/sakila'
# print(connection_string)
engine = create_engine(connection_string)

# %%
type(engine)
# Out:
# sqlalchemy.engine.base.Engine

# %% [markdown]
# # Create a query or queries to extract the information you think may be relevant for building the prediction model. It should include some film features and some rental features (X).

# %%
film_and_rental_query = '''
SELECT f.title, r.rental_date, f.rating, f.length, f.rental_duration, f.special_features, fc.category_id
FROM film f
LEFT JOIN inventory i
USING (film_id)
LEFT JOIN rental r
USING (inventory_id)
LEFT JOIN film_category fc
USING (film_id)
GROUP BY f.title

'''

# %%
# data = pd.read_sql_query(film_and_rental_query, engine)
# print(data.shape)
# data.head().T

# The bove query works in SQL workbench but not in jupyter notebook. 
# Hence after the query I saved the results in .csv file and read it.

data = pd.read_csv("Results.csv")
print(data.shape)
data.head()
# Out:
# (1000, 7)
#               title          rental_date rating  length  rental_duration  \
# 0  ACADEMY DINOSAUR  2005-07-08 19:03:15     PG      86                6
# 1    ACE GOLDFINGER  2005-08-01 04:24:47      G      48                3
# 2  ADAPTATION HOLES  2005-07-27 01:21:19  NC-17      50                7
# 3  AFFAIR PREJUDICE  2005-07-12 02:40:41      G     117                5
# 4       AFRICAN EGG  2005-05-28 07:53:38      G     130                6
#
#                    special_features  category_id
# 0  Deleted Scenes,Behind the Scenes            6
# 1           Trailers,Deleted Scenes           11
# 2           Trailers,Deleted Scenes            6
# 3    Commentaries,Behind the Scenes           11
# 4                    Deleted Scenes            8

# %% [markdown]
# # Create a query to get the list of all unique film titles and a boolean indicating if it was rented (rental_date) in May 2005. (Create new column called - 'rented_in_may'). This will be our TARGET (y) variable.

# %%
data.isna().sum()
# Out:
# title                0
# rental_date         42
# rating               0
# length               0
# rental_duration      0
# special_features     0
# category_id          0
# dtype: int64

# %%
data.dtypes
# Out:
# title               object
# rental_date         object
# rating              object
# length               int64
# rental_duration      int64
# special_features    object
# category_id          int64
# dtype: object

# %%
data["rental_date"] = pd.to_datetime(data["rental_date"])

# %%
data["rented_in_May"] = np.where((data["rental_date"].dt.month == 5), True, False)

# %%
data.head()
# Out:
#               title         rental_date rating  length  rental_duration  \
# 0  ACADEMY DINOSAUR 2005-07-08 19:03:15     PG      86                6
# 1    ACE GOLDFINGER 2005-08-01 04:24:47      G      48                3
# 2  ADAPTATION HOLES 2005-07-27 01:21:19  NC-17      50                7
# 3  AFFAIR PREJUDICE 2005-07-12 02:40:41      G     117                5
# 4       AFRICAN EGG 2005-05-28 07:53:38      G     130                6
#
#                    special_features  category_id  rented_in_May
# 0  Deleted Scenes,Behind the Scenes            6          False
# 1           Trailers,Deleted Scenes           11          False
# 2           Trailers,Deleted Scenes            6          False
# 3    Commentaries,Behind the Scenes           11          False
# 4                    Deleted Scenes            8           True

# %%
display(data.dtypes)
data.isna().sum()
# Out:
# title                       object
# rental_date         datetime64[ns]
# rating                      object
# length                       int64
# rental_duration              int64
# special_features            object
# category_id                  int64
# rented_in_May                 bool
# dtype: object
# title                0
# rental_date         42
# rating               0
# length               0
# rental_duration      0
# special_features     0
# category_id          0
# rented_in_May        0
# dtype: int64

# %% [markdown]
# # Read the data into a Pandas dataframe. At this point you should have 1000 rows. Number of columns depends on the number of features you chose.

# %%
data.shape
# Out:
# (1000, 8)

# %% [markdown]
# # Analyze extracted features (X) and transform them. You may need to encode some categorical variables, or scale numerical variables.

# %%
splited = pd.DataFrame(data['special_features'].values.tolist()).rename(columns={0:'special_features'})
display(type(splited))
splited = splited['special_features'].str.split(',', expand=True)
splited
# Out:
# pandas.core.frame.DataFrame
#                   0                  1                  2     3
# 0    Deleted Scenes  Behind the Scenes               None  None
# 1          Trailers     Deleted Scenes               None  None
# 2          Trailers     Deleted Scenes               None  None
# 3      Commentaries  Behind the Scenes               None  None
# 4    Deleted Scenes               None               None  None
# ..              ...                ...                ...   ...
# 995        Trailers  Behind the Scenes               None  None
# 996        Trailers  Behind the Scenes               None  None
# 997  Deleted Scenes               None               None  None
# 998        Trailers     Deleted Scenes               None  None
# 999        Trailers       Commentaries  Behind the Scenes  None
#
# [1000 rows x 4 columns]

# %%
splitted = data['special_features'].str.split(',', expand = True)
sp_columns = ["SP_1", "SP_2", "SP_3", "SP_4"]
splitted.columns = sp_columns
splitted
# Out:
#                SP_1               SP_2               SP_3  SP_4
# 0    Deleted Scenes  Behind the Scenes               None  None
# 1          Trailers     Deleted Scenes               None  None
# 2          Trailers     Deleted Scenes               None  None
# 3      Commentaries  Behind the Scenes               None  None
# 4    Deleted Scenes               None               None  None
# ..              ...                ...                ...   ...
# 995        Trailers  Behind the Scenes               None  None
# 996        Trailers  Behind the Scenes               None  None
# 997  Deleted Scenes               None               None  None
# 998        Trailers     Deleted Scenes               None  None
# 999        Trailers       Commentaries  Behind the Scenes  None
#
# [1000 rows x 4 columns]

# %%
data = pd.concat([data, splitted], axis = 1)
data
# Out:
#                  title         rental_date rating  length  rental_duration  \
# 0     ACADEMY DINOSAUR 2005-07-08 19:03:15     PG      86                6
# 1       ACE GOLDFINGER 2005-08-01 04:24:47      G      48                3
# 2     ADAPTATION HOLES 2005-07-27 01:21:19  NC-17      50                7
# 3     AFFAIR PREJUDICE 2005-07-12 02:40:41      G     117                5
# 4          AFRICAN EGG 2005-05-28 07:53:38      G     130                6
# ..                 ...                 ...    ...     ...              ...
# 995     YOUNG LANGUAGE 2005-07-08 23:51:26      G     183                6
# 996         YOUTH KICK 2005-07-27 10:21:15  NC-17     179                4
# 997       ZHIVAGO CORE 2005-06-17 03:19:20  NC-17     105                6
# 998  ZOOLANDER FICTION 2005-07-06 11:40:27      R     101                5
# 999          ZORRO ARK 2005-07-12 21:46:33  NC-17      50                3
#
#                             special_features  category_id  rented_in_May  \
# 0           Deleted Scenes,Behind the Scenes            6          False
# 1                    Trailers,Deleted Scenes           11          False
# 2                    Trailers,Deleted Scenes            6          False
# 3             Commentaries,Behind the Scenes           11          False
# 4                             Deleted Scenes            8           True
# ..                                       ...          ...            ...
# 995               Trailers,Behind the Scenes            6          False
# 996               Trailers,Behind the Scenes           12          False
# 997                           Deleted Scenes           11          False
# 998                  Trailers,Deleted Scenes            3          False
# 999  Trailers,Commentaries,Behind the Scenes            5          False
#
#                SP_1               SP_2               SP_3  SP_4
# 0    Deleted Scenes  Behind the Scenes               None  None
# 1          Trailers     Deleted Scenes               None  None
# 2          Trailers     Deleted Scenes               None  None
# 3      Commentaries  Behind the Scenes               None  None
# 4    Deleted Scenes               None               None  None
# ..              ...                ...                ...   ...
# 995        Trailers  Behind the Scenes               None  None
# 996        Trailers  Behind the Scenes               None  None
# 997  Deleted Scenes               None               None  None
# 998        Trailers     Deleted Scenes               None  None
# 999        Trailers       Commentaries  Behind the Scenes  None
#
# [1000 rows x 12 columns]

# %%
data = data.drop(["special_features"], axis = 1)
data
# Out:
#                  title         rental_date rating  length  rental_duration  \
# 0     ACADEMY DINOSAUR 2005-07-08 19:03:15     PG      86                6
# 1       ACE GOLDFINGER 2005-08-01 04:24:47      G      48                3
# 2     ADAPTATION HOLES 2005-07-27 01:21:19  NC-17      50                7
# 3     AFFAIR PREJUDICE 2005-07-12 02:40:41      G     117                5
# 4          AFRICAN EGG 2005-05-28 07:53:38      G     130                6
# ..                 ...                 ...    ...     ...              ...
# 995     YOUNG LANGUAGE 2005-07-08 23:51:26      G     183                6
# 996         YOUTH KICK 2005-07-27 10:21:15  NC-17     179                4
# 997       ZHIVAGO CORE 2005-06-17 03:19:20  NC-17     105                6
# 998  ZOOLANDER FICTION 2005-07-06 11:40:27      R     101                5
# 999          ZORRO ARK 2005-07-12 21:46:33  NC-17      50                3
#
#      category_id  rented_in_May            SP_1               SP_2  \
# 0              6          False  Deleted Scenes  Behind the Scenes
# 1             11          False        Trailers     Deleted Scenes
# 2              6          False        Trailers     Deleted Scenes
# 3             11          False    Commentaries  Behind the Scenes
# 4              8           True  Deleted Scenes               None
# ..           ...            ...             ...                ...
# 995            6          False        Trailers  Behind the Scenes
# 996           12          False        Trailers  Behind the Scenes
# 997           11          False  Deleted Scenes               None
# 998            3          False        Trailers     Deleted Scenes
# 999            5          False        Trailers       Commentaries
#
#                   SP_3  SP_4
# 0                 None  None
# 1                 None  None
# 2                 None  None
# 3                 None  None
# 4                 None  None
# ..                 ...   ...
# 995               None  None
# 996               None  None
# 997               None  None
# 998               None  None
# 999  Behind the Scenes  None
#
# [1000 rows x 11 columns]

# %%
data["rental_date"].value_counts(dropna = True)
# Out:
# 2005-07-08 19:03:15    1
# 2005-07-10 04:56:55    1
# 2005-07-12 08:33:49    1
# 2005-07-08 20:23:15    1
# 2005-07-31 06:41:46    1
#                       ..
# 2005-07-29 11:16:29    1
# 2005-05-27 10:23:25    1
# 2005-06-16 17:49:57    1
# 2005-05-31 07:33:25    1
# 2005-07-12 21:46:33    1
# Name: rental_date, Length: 958, dtype: int64

# %% [markdown]
# # Creating features and target

# %%
# Target
y = data["rented_in_May"]

# Features. (dropping rental_date as we are analysing only on rented_in_May column)
X = data.drop(["rented_in_May", "rental_date"], axis = 1)
